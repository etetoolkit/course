# %% [markdown]
# # Building a concatenate species tree with ete build
# Besides the reconstruction of gene phylogenies, ETE build provides basic workflows to build concatenated trees.
# You only need to provide a file defining the target COGs to use. This is, a file where each lines contains a tab-delimited list of sequences that are considered orthologs among all taxa.
#
# - Relevant documentation: [ete3 build supermatrix](http://etetoolkit.org/cookbook/ete_build_supermatrix.ipynb)

# %% [markdown]
# # Infer species tree based on a concatenated alignment of marker gene families

# %% [markdown]
# ## Create a COGS file that ete build can read
# To play well with ETE, the COGs file should contain sequences names where the species code can be easily extracted.
#
# Remember that, in our case, all sequences have the following format:
#
# - `spcode.seqname`, where `.` acts as a delimiter.

# %%
# Load trees and marker trees
import pickle

def extract_spcode(nodename):
    return nodename.split('.')[0]

all_trees = pickle.load(open('data/alltrees.pkl', 'rb'))
sptree_markers = pickle.load(open('data/sptree_markers.pkl', 'rb'))

# %% [markdown]
# ## Create a COGS file that ete build can read

# %%
# TASK: Create a text file where each line contains a tab-delimited list of sequences of a marker gene family (COG)
# Save the file as "data/marker_cogs.tsv" in your data folder

with open('data/marker_cogs.tsv', 'w') as COGS:
    for tname in sptree_markers: 
        t = all_trees[tname]
        print('\t'.join(t.get_leaf_names()), file=COGS)

# %%
# Let's have a look at the COGs file
# !head data/marker_cogs.tsv
# Out:
# 933801.Ahos_0739	273063.STK_02680	673860.AciM339_0977	263820.PTO0416	1051632.TPY_0322	224324999.sul008	224324.aq_008	525897.Dbac_2775	743299.Acife_2711	637389.Acaty_c0617	555778.Hneap_0322	1255043.TVNIR_2575	713587.THITH_14295	1158165.KB898880_gene1474	1121405.dsmv_3590
# 273063.STK_04260	933801.Ahos_0848	673860.AciM339_1102	263820.PTO0644	1121405.dsmv_3585	525897.Dbac_2770	224324999.sul015	224324.aq_015	1051632.TPY_0327	1158165.KB898880_gene1479	1255043.TVNIR_2570	713587.THITH_14270	555778.Hneap_0327	637389.Acaty_c0622	743299.Acife_2706
# 273063.STK_04220	933801.Ahos_0854	263820.PTO0650	673860.AciM339_1108	224324.aq_1654	224324999.sul1654	525897.Dbac_2764	637389.Acaty_c0628	743299.Acife_2700	555778.Hneap_0333	713587.THITH_14240	1255043.TVNIR_2564	1158165.KB898880_gene1485	1121405.dsmv_3579	1051632.TPY_0333
# 933801.Ahos_0662	273063.STK_20680	673860.AciM339_1558	263820.PTO1221	555778.Hneap_0345	637389.Acaty_c0643	743299.Acife_2685	1255043.TVNIR_2552	713587.THITH_14175	1158165.KB898880_gene1497	525897.Dbac_2751	224324999.sul073	224324.aq_073	1051632.TPY_0348	1121405.dsmv_3566
# 933801.Ahos_0664	273063.STK_20700	673860.AciM339_1560	263820.PTO1219	224324999.sul074	224324.aq_074	1051632.TPY_0347	743299.Acife_2686	637389.Acaty_c0642	555778.Hneap_0344	1255043.TVNIR_2553	1158165.KB898880_gene1496	713587.THITH_14180	525897.Dbac_2752	1121405.dsmv_3567
# 933801.Ahos_0659	273063.STK_20650	673860.AciM339_1029	263820.PTO0323	525897.Dbac_0049	1121405.dsmv_2426	1051632.TPY_0368	224324.aq_1877	224324999.sul1877	1158165.KB898875_gene68	713587.THITH_03880	1255043.TVNIR_3188	555778.Hneap_2044	743299.Acife_3087	637389.Acaty_c0470
# 224324999.sul1590	224324.aq_1590	1121405.dsmv_0203	525897.Dbac_2890	1158165.KB898872_gene767	713587.THITH_11925	1255043.TVNIR_0872	555778.Hneap_2190	743299.Acife_1511	637389.Acaty_c1132	263820.PTO1283	673860.AciM339_1327	1051632.TPY_1759	933801.Ahos_0752	273063.STK_02800
# 273063.STK_13680	933801.Ahos_1295	263820.PTO0437	673860.AciM339_0145	224324.aq_1933	224324999.sul1933	1051632.TPY_0300	743299.Acife_2721	637389.Acaty_c0607	1158165.KB898884_gene2556	555778.Hneap_0312	1255043.TVNIR_2585	713587.THITH_14345	1121405.dsmv_3649	525897.Dbac_2785
# 273063.STK_03940	933801.Ahos_0726	263820.PTO0714	673860.AciM339_0319	224324.aq_132	224324999.sul132	1051632.TPY_0230	1121405.dsmv_1592	525897.Dbac_0059	743299.Acife_2731	637389.Acaty_c0594	555778.Hneap_1866	1158165.KB898872_gene937	1255043.TVNIR_0990	713587.THITH_11630
# 933801.Ahos_0520	273063.STK_04720	263820.PTO1061	673860.AciM339_1250	224324999.sul527	224324.aq_527	637389.Acaty_c2204	743299.Acife_2485	555778.Hneap_0590	1158165.KB898871_gene2506	713587.THITH_01500	1255043.TVNIR_3592	1051632.TPY_0961	525897.Dbac_3477	1121405.dsmv_2875

# %% [markdown]
# ## Use ete build to infer a supermatrix tree out of your marker families
#
# - specify a gene tree workflow (for the gene alignment)
# - specify a supermatrix workflow (how to concatenate COGs and program use to infer the final tree)

# %%
# TASK: Execute ete build to infer a species tree out of the marker COGs
# !ete3 build -w mafft_default-none-none-none -m sptree_fasttree_all -o data/sptree \
           --cogs data/marker_cogs.tsv -a data/all_prots.faa --spname-delimiter . --clearall --cpu 5 --noimg
# Out:
# Toolchain path: /home/huerta/eteconda/envs/etecourse/bin/ete3_apps/bin
# Toolchain version: unknown
# ['mafft_default-none-none-none']
# ['cog_all-alg_concat_default-fasttree_full']
#
#       --------------------------------------------------------------------------------
#                   ETE build (3.1.2) - reproducible phylogenetic workflows
#
#       Citation:
#
#        Huerta-Cepas J, Serra F and Bork P. ETE 3: Reconstruction, analysis and
#        visualization of phylogenomic data. Mol Biol Evol (2016)
#        doi:10.1093/molbev/msw046
#
#       (Note that a list of the external programs used to complete all necessary
#       computations will be shown after workflow execution. Those programs should
#       also be cited.)
#
#       --------------------------------------------------------------------------------
#
# INFO -  Testing x86-64  portable applications...
#        clustalo: OK - 1.2.4
#       dialigntx: OK - This is DIALIGN-TX Version 1.0.2 - A Multiple Sequence alignment program.
#        fasttree: OK - Usage for FastTree version 2.1.8 Double precision (No SSE3), OpenMP (2 threads):
#          iqtree: OK - IQ-TREE multicore version 1.5.5 for Linux 64-bit built Jun  2 2017
#          kalign: OK - Kalign version 2.04, Copyright (C) 2004, 2005, 2006 Timo Lassmann
#           mafft: OK - MAFFT v6.861b (2011/09/24)
#          muscle: OK - MUSCLE v3.8.31 by Robert C. Edgar
#           phyml: OK - . This is PhyML version 20160115.
#      pmodeltest: OK - pmodeltest.py v1.4
#           raxml: OK - This is RAxML version 8.2.11 released by Alexandros Stamatakis on June 2017.
#  raxml-pthreads: OK - This is RAxML version 8.2.11 released by Alexandros Stamatakis on June 2017.
#          readal: OK - readAl v1.4.rev6 build[2012-02-02]
#          statal: OK - statAl v1.4.rev6 build[2012-02-02]
#         tcoffee: MISSING
#          trimal: OK - trimAl v1.4.rev6 build[2012-02-02]
#
# WARNING: 1 external tools seem to be missing or unfunctional
# Install using conda (recomended):
#  conda install -c etetoolkit ete3_external_apps
# or manually compile by running:
#  ete3 upgrade-external-tools
#
# INFO -  Starting ETE-build execution at Tue Sep  1 12:41:55 2020
# INFO -  Output directory /home/huerta/etecourse/course/nb/03-building_concat_species_trees/data/sptree
# INFO -  Erasing all existing npr data...
# WRNG -  COG file restriction: 495 sequences from 15 species
# INFO -  Reading aa sequences from data/all_prots.faa...
# loaded:0000150 skipped:0009850 scanned:0010000 30.3%
# loaded:0000275 skipped:0019725 scanned:0020000 55.6%
# loaded:0000390 skipped:0029610 scanned:0030000 78.8%
# loaded:0000490 skipped:0039510 scanned:0040000 99.0%
#
#
# WRNG -  495 target sequences
# INFO -  ETE build starts now!
# INFO -   Updating tasks status: (Tue Sep  1 12:41:55 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) CogSelectorTask (15 species, MCL-COGs, /cog_all-al...ttree_full)
# INFO -  Launched 0 jobs. 0(R), 0(W). Cores usage: 0/5
# INFO -                     933801  found in single copy in      33 (97.1%) COGs
# INFO -                     273063  found in single copy in      33 (97.1%) COGs
# INFO -                     673860  found in single copy in      33 (97.1%) COGs
# INFO -                     263820  found in single copy in      33 (97.1%) COGs
# INFO -                    1051632  found in single copy in      33 (97.1%) COGs
# INFO -                  224324999  found in single copy in      33 (97.1%) COGs
# INFO -                     224324  found in single copy in      33 (97.1%) COGs
# INFO -                     525897  found in single copy in      33 (97.1%) COGs
# INFO -                     743299  found in single copy in      33 (97.1%) COGs
# INFO -                     637389  found in single copy in      33 (97.1%) COGs
# INFO -                     555778  found in single copy in      33 (97.1%) COGs
# INFO -                    1255043  found in single copy in      33 (97.1%) COGs
# INFO -                     713587  found in single copy in      33 (97.1%) COGs
# INFO -                    1158165  found in single copy in      33 (97.1%) COGs
# INFO -                    1121405  found in single copy in      33 (97.1%) COGs
# INFO -       Largest cog size: 15. Smallest cog size: 15
# INFO -       Analysis of current COG selection:
# INFO -                                555778 species present in     33 COGs (100.0%)
# INFO -                               1255043 species present in     33 COGs (100.0%)
# INFO -                                263820 species present in     33 COGs (100.0%)
# INFO -                                525897 species present in     33 COGs (100.0%)
# INFO -                                273063 species present in     33 COGs (100.0%)
# INFO -                                673860 species present in     33 COGs (100.0%)
# INFO -                               1121405 species present in     33 COGs (100.0%)
# INFO -                               1158165 species present in     33 COGs (100.0%)
# INFO -                                933801 species present in     33 COGs (100.0%)
# INFO -                             224324999 species present in     33 COGs (100.0%)
# INFO -                                224324 species present in     33 COGs (100.0%)
# INFO -                               1051632 species present in     33 COGs (100.0%)
# INFO -                                713587 species present in     33 COGs (100.0%)
# INFO -                                743299 species present in     33 COGs (100.0%)
# INFO -                                637389 species present in     33 COGs (100.0%)
# INFO -        33 COGs selected with at least 0 species out of 15
# INFO -        Average COG size 15.0/15.0 +- 0.0
# INFO -   (D) CogSelectorTask (15 species, MCL-COGs, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:41:57 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 31(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:41:59 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 29(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:01 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:03 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 27(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:05 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 25(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:07 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:09 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 23(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:11 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 21(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:13 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:15 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 19(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:17 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 17(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:19 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:22 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 15(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:24 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 13(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:26 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:28 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 11(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:30 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 9(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:32 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:34 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 7(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:36 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 5(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:38 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:40 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 3(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:42 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  waiting for 2 cores
# INFO -  Launched 2 jobs. 2(R), 1(W). Cores usage: 4/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:44 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 1 jobs. 1(R), 0(W). Cores usage: 2/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:46 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# WRNG -       Concatenating alignments
# WRNG -       Using aa concatenated alignment
# INFO -   (D) ConcatAlgTask (15 species, 33 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:48 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 1 jobs. 1(R), 0(W). Cores usage: 2/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:50 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 0 jobs. 1(R), 0(W). Cores usage: 2/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:52 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:42:54 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 0 jobs. 1(R), 0(W). Cores usage: 2/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:56 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 0 jobs. 1(R), 0(W). Cores usage: 2/5
# INFO -   Updating tasks status: (Tue Sep  1 12:42:58 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:43:00 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 0 jobs. 1(R), 0(W). Cores usage: 2/5
# INFO -   Updating tasks status: (Tue Sep  1 12:43:02 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 0 jobs. 1(R), 0(W). Cores usage: 2/5
# INFO -   Updating tasks status: (Tue Sep  1 12:43:04 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Tue Sep  1 12:43:06 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 0 jobs. 0(R), 0(W). Cores usage: 0/5
# INFO -   Updating tasks status: (Tue Sep  1 12:43:08 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -   (D) TreeTask (15 aa seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Launched 0 jobs. 0(R), 0(W). Cores usage: 0/5
# INFO -   Updating tasks status: (Tue Sep  1 12:43:10 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) TreeMergeTask (15 aa seqs, TreeMerger, /cog_all-al...ttree_full)
# INFO -   (D) TreeMergeTask (15 aa seqs, TreeMerger, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Assembling final tree...
# INFO -  Done thread cog_all-alg_concat_default-fasttree_full in 1 iteration(s)
# INFO -  Writing final tree for cog_all-alg_concat_default-fasttree_full
#    /home/huerta/etecourse/course/nb/03-building_concat_species_trees/data/sptree/cog_all-alg_concat_default-fasttree_full/all_prots.faa.final_tree.nw
#    /home/huerta/etecourse/course/nb/03-building_concat_species_trees/data/sptree/cog_all-alg_concat_default-fasttree_full/all_prots.faa.final_tree.nwx (newick extended)
# INFO -  Writing root node alignment cog_all-alg_concat_default-fasttree_full
#    /home/huerta/etecourse/course/nb/03-building_concat_species_trees/data/sptree/cog_all-alg_concat_default-fasttree_full/all_prots.faa.final_tree.fa
# INFO -  Done
# INFO -  Deleting temporal data...
#    ========================================================================
#          The following published software and/or methods were used.
#                *** Please, do not forget to cite them! ***
#    ========================================================================
#    Huerta-Cepas J, Serra F, Bork P. ETE 3: Reconstruction, analysis and
#       visualization of phylogenomic data. Mol Biol Evol (2016) doi:
#       10.1093/molbev/msw046
#    Katoh K, Kuma K, Toh H, Miyata T. MAFFT version 5: improvement in
#       accuracy of multiple sequence alignment. Nucleic Acids Res. 2005 Jan
#       20;33(2):511-8.
#    Price MN, Dehal PS, Arkin AP. FastTree 2 - approximately maximum-
#       likelihood trees for large alignments. PLoS One. 2010 Mar
#       10;5(3):e9490.

# %% [markdown]
# You can also use codon alignments to infer the tree based on nucleotide rather than amino acid residues (useful when sequences are too similar)

# %%
# TASK: Execute ete build to infer a species tree out of the marker COGs, using codon alignments and nt sequences
# !ete3 build -w mafft_default-none-none-none -m sptree_fasttree_all -o data/sptree \
           --cogs data/marker_cogs.tsv -a data/all_prots.faa -n data/all_prots.fna --nt-switch-threshold 0.0 \
           --spname-delimiter . --clearall --cpu 5 --noimg
# Out:
# Toolchain path: /home/huerta/miniconda3/envs/eccb20/bin/ete3_apps/bin
# Toolchain version: unknown
# ['mafft_default-none-none-none']
# ['cog_all-alg_concat_default-fasttree_full']
#
#       --------------------------------------------------------------------------------
#                   ETE build (3.1.2) - reproducible phylogenetic workflows
#
#       Citation:
#
#        Huerta-Cepas J, Serra F and Bork P. ETE 3: Reconstruction, analysis and
#        visualization of phylogenomic data. Mol Biol Evol (2016)
#        doi:10.1093/molbev/msw046
#
#       (Note that a list of the external programs used to complete all necessary
#       computations will be shown after workflow execution. Those programs should
#       also be cited.)
#
#       --------------------------------------------------------------------------------
#
# INFO -  Testing x86-64  portable applications...
#        clustalo: OK - 1.2.4
#       dialigntx: OK - This is DIALIGN-TX Version 1.0.2 - A Multiple Sequence alignment program.
#        fasttree: OK - FastTree Version 2.1.8 Double precision (No SSE3), OpenMP (2 threads)
#          iqtree: OK - IQ-TREE multicore version 1.5.5 for Linux 64-bit built Jun  2 2017
#          kalign: OK - Kalign version 2.04, Copyright (C) 2004, 2005, 2006 Timo Lassmann
#           mafft: OK - MAFFT v6.861b (2011/09/24)
#          muscle: OK - MUSCLE v3.8.31 by Robert C. Edgar
#           phyml: OK - . This is PhyML version 20160115.
#      pmodeltest: OK - pmodeltest.py v1.4
#           raxml: OK - This is RAxML version 8.2.11 released by Alexandros Stamatakis on June 2017.
#  raxml-pthreads: OK - This is RAxML version 8.2.11 released by Alexandros Stamatakis on June 2017.
#          readal: OK - readAl v1.4.rev6 build[2012-02-02]
#          statal: OK - statAl v1.4.rev6 build[2012-02-02]
#         tcoffee: OK - PROGRAM: T-COFFEE Version_11.00.8cbe486 (2014-08-12 22:05:29 - Revision 8cbe486 - Build 477)
#          trimal: OK - trimAl v1.4.rev6 build[2012-02-02]
# INFO -  Starting ETE-build execution at Sun Aug 30 17:07:46 2020
# INFO -  Output directory /home/huerta/_Devel/etecourse/nb/03-building_concat_species_trees/data/sptree
# INFO -  Erasing all existing npr data...
# WRNG -  Using existing dir: /home/huerta/_Devel/etecourse/nb/03-building_concat_species_trees/data/sptree/db
# WRNG -  COG file restriction: 510 sequences from 15 species
# INFO -  Reading aa sequences from data/all_prots.faa...
# loaded:0000136 skipped:0009864 scanned:0010000 26.7%
# loaded:0000272 skipped:0019728 scanned:0020000 53.3%
# loaded:0000393 skipped:0029607 scanned:0030000 77.1%
# loaded:0000505 skipped:0039495 scanned:0040000 99.0%
#
#
# INFO -  Reading nt sequences from data/all_prots.fna...
# loaded:0000135 skipped:0009865 scanned:0010000 26.5%
# loaded:0000271 skipped:0019729 scanned:0020000 53.1%
# loaded:0000374 skipped:0029626 scanned:0030000 73.3%
# loaded:0000490 skipped:0039510 scanned:0040000 96.1%
#
#
# WRNG -  510 target sequences
# INFO -  ETE build starts now!
# INFO -   Updating tasks status: (Sun Aug 30 17:07:46 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) CogSelectorTask (15 species, MCL-COGs, /cog_all-al...ttree_full)
# INFO -                     933801  found in single copy in      34 (97.1%) COGs
# INFO -                     273063  found in single copy in      34 (97.1%) COGs
# INFO -                     263820  found in single copy in      34 (97.1%) COGs
# INFO -                     673860  found in single copy in      34 (97.1%) COGs
# INFO -                    1051632  found in single copy in      34 (97.1%) COGs
# INFO -                  224324999  found in single copy in      34 (97.1%) COGs
# INFO -                     224324  found in single copy in      34 (97.1%) COGs
# INFO -                     525897  found in single copy in      34 (97.1%) COGs
# INFO -                     637389  found in single copy in      34 (97.1%) COGs
# INFO -                     743299  found in single copy in      34 (97.1%) COGs
# INFO -                     555778  found in single copy in      34 (97.1%) COGs
# INFO -                    1158165  found in single copy in      34 (97.1%) COGs
# INFO -                     713587  found in single copy in      34 (97.1%) COGs
# INFO -                    1255043  found in single copy in      34 (97.1%) COGs
# INFO -                    1121405  found in single copy in      34 (97.1%) COGs
# INFO -       Largest cog size: 15. Smallest cog size: 15
# INFO -       Analysis of current COG selection:
# INFO -                                713587 species present in     34 COGs (100.0%)
# INFO -                             224324999 species present in     34 COGs (100.0%)
# INFO -                                933801 species present in     34 COGs (100.0%)
# INFO -                                224324 species present in     34 COGs (100.0%)
# INFO -                                555778 species present in     34 COGs (100.0%)
# INFO -                                273063 species present in     34 COGs (100.0%)
# INFO -                                525897 species present in     34 COGs (100.0%)
# INFO -                                263820 species present in     34 COGs (100.0%)
# INFO -                                637389 species present in     34 COGs (100.0%)
# INFO -                                743299 species present in     34 COGs (100.0%)
# INFO -                               1051632 species present in     34 COGs (100.0%)
# INFO -                               1121405 species present in     34 COGs (100.0%)
# INFO -                               1255043 species present in     34 COGs (100.0%)
# INFO -                               1158165 species present in     34 COGs (100.0%)
# INFO -                                673860 species present in     34 COGs (100.0%)
# INFO -        34 COGs selected with at least 0 species out of 15
# INFO -        Average COG size 15.0/15.0 +- 0.0
# INFO -   (D) CogSelectorTask (15 species, MCL-COGs, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:07:48 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:07:51 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.66 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.66 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:07:53 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.61 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:07:55 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.57 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:07:57 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.69 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.64 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:07:59 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:01 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.72 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.69 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:03 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.64 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.67 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:05 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.68 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.69 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:07 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:09 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.65 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.63 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:11 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.71 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.66 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:13 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:15 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.66 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.59 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:17 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.66 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.65 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:19 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:21 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.70 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.63 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:23 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.68 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.51 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:26 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:28 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.75 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.60 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:30 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.55 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.58 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:32 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:34 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.60 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.59 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:36 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.65 >= 0.00
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.69 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:38 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (Q) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.52 >= 0.00
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:40 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -          Switching to codon alignment! amino-acid sequence similarity: 0.62 >= 0.00
# WRNG -       Concatenating alignments
# WRNG -       Using nt concatenated alignment
# INFO -   (D) ConcatAlgTask (15 species, 34 COGs, ConcatAlg, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:42 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:44 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:46 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:48 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:50 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:52 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:54 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:56 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:08:58 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (R) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -   (D) TreeTask (15 nt seqs, FastTree, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -   Updating tasks status: (Sun Aug 30 17:09:00 2020)
# INFO -  Thread cog_all-alg_concat_default-fasttree_full: pending tasks: 1 of sizes: 15
# INFO -   (W) TreeMergeTask (15 nt seqs, TreeMerger, /cog_all-al...ttree_full)
# INFO -   (D) TreeMergeTask (15 nt seqs, TreeMerger, /cog_all-al...ttree_full)
# INFO -  Waiting 2 seconds
# INFO -  Assembling final tree...
# INFO -  Done thread cog_all-alg_concat_default-fasttree_full in 1 iteration(s)
# INFO -  Writing final tree for cog_all-alg_concat_default-fasttree_full
#    /home/huerta/_Devel/etecourse/nb/03-building_concat_species_trees/data/sptree/cog_all-alg_concat_default-fasttree_full/all_prots.faa.final_tree.nw
#    /home/huerta/_Devel/etecourse/nb/03-building_concat_species_trees/data/sptree/cog_all-alg_concat_default-fasttree_full/all_prots.faa.final_tree.nwx (newick extended)CPU times: user 1.67 ms, sys: 5.17 ms, total: 6.84 ms
# Wall time: 1min 16s

# %%
# !cp "data/sptree/cog_all-alg_concat_default-fasttree_full/all_prots.faa.final_tree.nw" "data/sptree.nw" 

# !ete3 annotate --ncbi -t "data/sptree.nw"| ete3 view --ncbi
# Out:
# Traceback (most recent call last):
#   File "/home/huerta/miniconda3/envs/etecourse/bin/ete3", line 8, in <module>
#     sys.exit(main())
#   File "/home/huerta/miniconda3/envs/etecourse/lib/python3.6/site-packages/ete3/tools/ete.py", line 95, in main
#     _main(sys.argv)
#   File "/home/huerta/miniconda3/envs/etecourse/lib/python3.6/site-packages/ete3/tools/ete.py", line 269, in _main
#     args.func(args)
#   File "/home/huerta/miniconda3/envs/etecourse/lib/python3.6/site-packages/ete3/tools/ete_annotate.py", line 61, in run
#     tree.annotate_ncbi_taxa(args.taxid_attr)
#   File "/home/huerta/miniconda3/envs/etecourse/lib/python3.6/site-packages/ete3/phylo/phylotree.py", line 798, in annotate_ncbi_taxa
#     return ncbi.annotate_tree(self, taxid_attr=taxid_attr, tax2name=tax2name, tax2track=tax2track, tax2rank=tax2rank)
#   File "/home/huerta/miniconda3/envs/etecourse/lib/python3.6/site-packages/ete3/ncbi_taxonomy/ncbiquery.py", line 545, in annotate_tree
#     lineage = tax2track[node_taxid],
# KeyError: 224324999

# %% [markdown]
# And, of course, you can load the species tree and operate with it

# %%
from ete3 import PhyloTree
t = PhyloTree("data/sptree/cog_all-alg_concat_default-fasttree_full/all_prots.faa.final_tree.nw")

# Phylogenetic distance from our strain to the reference genome:
print(t.get_distance("224324999", "224324"))

# Phylogenetic distance from all taxa
print("Cophenetic distance matrix:\n",  t.cophenetic_matrix())
# Out:
# 0.0
# Cophenetic distance matrix:
#  ([[0, 0.9269901, 0.9766983999999999, 1.0198972, 0.992823, 0.992823, 1.776664, 1.8348280000000001, 0.9181431, 1.0569824, 0.9746603, 1.7396190000000002, 1.0144897, 1.0255883, 1.8264490000000002], [0.9269901, 0, 0.8590059, 0.9022047000000001, 1.0524091, 1.0524091, 1.8362501, 1.8944141, 0.6481650000000001, 0.9392898999999999, 0.8569678000000001, 1.7992051, 0.8967972000000001, 0.9078958, 1.8860351], [0.9766983999999999, 0.8590059, 0, 0.2902328, 1.1021174, 1.1021174, 1.8859584000000003, 1.9441224, 0.8501588999999999, 0.56747, 0.6050761, 1.8489134000000003, 0.2848253, 0.6560041, 1.9357434], [1.0198972, 0.9022047000000001, 0.2902328, 0, 1.1453162, 1.1453162, 1.9291572000000001, 1.9873212000000002, 0.8933577, 0.6106688000000001, 0.6482749000000001, 1.8921122000000001, 0.0933881, 0.6992029000000001, 1.9789422], [0.992823, 1.0524091, 1.1021174, 1.1453162, 0, 0.0, 1.351439, 1.4096030000000002, 1.0435621, 1.1824013999999998, 1.1000793, 1.314394, 1.1399086999999999, 1.1510072999999998, 1.401224], [0.992823, 1.0524091, 1.1021174, 1.1453162, 0.0, 0, 1.351439, 1.4096030000000002, 1.0435621, 1.1824013999999998, 1.1000793, 1.314394, 1.1399086999999999, 1.1510072999999998, 1.401224], [1.776664, 1.8362501, 1.8859584000000003, 1.9291572000000001, 1.351439, 1.351439, 0, 1.070012, 1.8274031, 1.9662424, 1.8839203, 0.753939, 1.9237497000000001, 1.9348482999999999, 1.061633], [1.8348280000000001, 1.8944141, 1.9441224, 1.9873212000000002, 1.4096030000000002, 1.4096030000000002, 1.070012, 0, 1.8855671000000003, 2.0244064, 1.9420843000000003, 1.032967, 1.9819137000000002, 1.9930123000000002, 0.41210899999999995], [0.9181431, 0.6481650000000001, 0.8501588999999999, 0.8933577, 1.0435621, 1.0435621, 1.8274031, 1.8855671000000003, 0, 0.9304429000000001, 0.8481208, 1.7903581, 0.8879502, 0.8990488, 1.8771881], [1.0569824, 0.9392898999999999, 0.56747, 0.6106688000000001, 1.1824013999999998, 1.1824013999999998, 1.9662424, 2.0244064, 0.9304429000000001, 0, 0.6853601, 1.9291974, 0.6052613000000001, 0.7362881, 2.0160274], [0.9746603, 0.8569678000000001, 0.6050761, 0.6482749000000001, 1.1000793, 1.1000793, 1.8839203, 1.9420843000000003, 0.8481208, 0.6853601, 0, 1.8468753, 0.6428674000000001, 0.367772, 1.9337053], [1.7396190000000002, 1.7992051, 1.8489134000000003, 1.8921122000000001, 1.314394, 1.314394, 0.753939, 1.032967, 1.7903581, 1.9291974, 1.8468753, 0, 1.8867047000000001, 1.8978032999999999, 1.024588], [1.0144897, 0.8967972000000001, 0.2848253, 0.0933881, 1.1399086999999999, 1.1399086999999999, 1.9237497000000001, 1.9819137000000002, 0.8879502, 0.6052613000000001, 0.6428674000000001, 1.8867047000000001, 0, 0.6937954000000001, 1.9735347000000003], [1.0255883, 0.9078958, 0.6560041, 0.6992029000000001, 1.1510072999999998, 1.1510072999999998, 1.9348482999999999, 1.9930123000000002, 0.8990488, 0.7362881, 0.367772, 1.8978032999999999, 0.6937954000000001, 0, 1.9846332999999998], [1.8264490000000002, 1.8860351, 1.9357434, 1.9789422, 1.401224, 1.401224, 1.061633, 0.41210899999999995, 1.8771881, 2.0160274, 1.9337053, 1.024588, 1.9735347000000003, 1.9846332999999998, 0]], ['1051632', '1121405', '1158165', '1255043', '224324', '224324999', '263820', '273063', '525897', '555778', '637389', '673860', '713587', '743299', '933801'])
